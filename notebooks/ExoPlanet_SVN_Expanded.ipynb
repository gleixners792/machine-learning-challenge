# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
#df.head()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %%
#df.info()

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_co',  'koi_fpflag_nt',  'koi_fpflag_ss',  'koi_model_snr',  'koi_prad',  'koi_duration_err2',  'koi_prad_err2',  'koi_duration_err1',  'koi_steff_err1',  'koi_fpflag_ec',  'koi_prad_err1',  'koi_steff_err2',  'koi_time0bk_err2',  'koi_period',  'koi_time0bk_err1',  'koi_duration',  'koi_period_err1',  'koi_depth',  'koi_period_err2',  'koi_impact',  'koi_insol_err1',  'koi_insol',  'koi_teq',  'koi_insol_err2',  'koi_time0bk']]
selected_features
# Out:
#       koi_fpflag_co  koi_fpflag_nt  koi_fpflag_ss  koi_model_snr  koi_prad  \
# 0                 0              0              0           25.8      2.83
# 1                 0              0              1           76.3     14.60
# 2                 0              0              1          505.6     33.46
# 3                 0              0              0           40.9      2.75
# 4                 0              0              0           40.2      2.77
# ...             ...            ...            ...            ...       ...
# 6986              0              0              0            8.4      1.11
# 6987              1              0              1          453.3     29.35
# 6988              0              0              0           10.6      0.72
# 6989              1              0              0           12.3      1.07
# 6990              1              0              0            8.2      1.05
#
#       koi_duration_err2  koi_prad_err2  koi_duration_err1  koi_steff_err1  \
# 0              -0.11600          -0.19            0.11600              81
# 1              -0.03410          -1.31            0.03410             158
# 2              -0.00537          -2.83            0.00537             157
# 3              -0.04200          -0.35            0.04200             169
# 4              -0.06730          -0.30            0.06730             189
# ...                 ...            ...                ...             ...
# 6986           -0.63400          -0.23            0.63400             169
# 6987           -0.01740          -2.57            0.01740             139
# 6988           -0.22900          -0.08            0.22900             165
# 6989           -0.16200          -0.11            0.16200             193
# 6990           -0.28300          -0.12            0.28300             158
#
#       koi_fpflag_ec  ...  koi_duration  koi_period_err1  koi_depth  \
# 0                 0  ...       4.50700     2.479000e-04      874.8
# 1                 0  ...       1.78220     1.490000e-05    10829.0
# 2                 0  ...       2.40641     2.630000e-07     8079.2
# 3                 0  ...       1.65450     3.760000e-06      603.3
# 4                 0  ...       3.14020     1.050000e-05      686.0
# ...             ...  ...           ...              ...        ...
# 6986              1  ...       4.80600     1.846000e-04       87.7
# 6987              0  ...       3.22210     1.160000e-07     1579.2
# 6988              0  ...       3.11400     1.780000e-05       48.5
# 6989              0  ...       0.86500     2.430000e-06      103.6
# 6990              1  ...       3.07800     6.360000e-05       76.7
#
#       koi_period_err2  koi_impact  koi_insol_err1  koi_insol  koi_teq  \
# 0       -2.479000e-04       0.586            2.87       9.11      443
# 1       -1.490000e-05       0.969           31.04      39.30      638
# 2       -2.630000e-07       1.276          668.95     891.96     1395
# 3       -3.760000e-06       0.701          874.33     926.16     1406
# 4       -1.050000e-05       0.762          420.33     427.65     1160
# ...               ...         ...             ...        ...      ...
# 6986    -1.846000e-04       0.765          152.77     176.40      929
# 6987    -1.160000e-07       1.252         3406.38    4500.53     2088
# 6988    -1.780000e-05       0.043         1537.86    1585.81     1608
# 6989    -2.430000e-06       0.147         5675.74    5713.41     2218
# 6990    -6.360000e-05       0.134          600.39     607.42     1266
#
#       koi_insol_err2  koi_time0bk
# 0              -1.62   162.513840
# 1             -10.49   175.850252
# 2            -230.35   170.307565
# 3            -314.24   171.595550
# 4            -136.70   172.979370
# ...              ...          ...
# 6986          -77.60   132.016100
# 6987        -1175.26   131.705093
# 6988         -502.22   133.001270
# 6989        -1836.94   132.181750
# 6990         -194.33   135.993300
#
# [6991 rows x 25 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
disposition = df["koi_disposition"]
disposition_names = ["CANDIDATE", "CONFIRMED", "FALSE POSITIVE"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selected_features, disposition, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_co  koi_fpflag_nt  koi_fpflag_ss  koi_model_snr  koi_prad  \
# 6122              0              0              0           10.8      1.24
# 6370              0              0              1           13.8      0.86
# 2879              0              1              0          254.3      3.21
# 107               0              0              0           38.4      2.25
# 29                0              0              0          696.5     12.21
#
#       koi_duration_err2  koi_prad_err2  koi_duration_err1  koi_steff_err1  \
# 6122            -0.3060          -0.23             0.3060             154
# 6370            -0.2820          -0.06             0.2820             158
# 2879             0.0000          -0.32             0.0000             151
# 107             -0.0595          -0.14             0.0595              76
# 29              -0.0075          -1.46             0.0075              77
#
#       koi_fpflag_ec  ...  koi_duration  koi_period_err1  koi_depth  \
# 6122              0  ...       3.61600     7.380000e-05      123.1
# 6370              1  ...       2.30900     6.060000e-06      114.6
# 2879              0  ...      79.89690     6.540000e-05      641.1
# 107               0  ...       2.63120     1.910000e-05      875.4
# 29                0  ...       2.22739     5.150000e-07     9802.0
#
#       koi_period_err2  koi_impact  koi_insol_err1  koi_insol  koi_teq  \
# 6122    -7.380000e-05       0.150          204.89     253.30     1017
# 6370    -6.060000e-06       0.291         2253.61    2891.64     1867
# 2879    -6.540000e-05       0.970          195.16     226.81      989
# 107     -1.910000e-05       0.300            7.15      55.37      696
# 29      -5.150000e-07       0.831          146.52     349.40     1103
#
#       koi_insol_err2  koi_time0bk
# 6122         -103.87   133.077240
# 6370         -677.78   132.020050
# 2879          -64.34   134.460380
# 107           -10.12   174.662240
# 29            -93.21   172.258529
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Pre-processing
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scale = X_minmax.transform(X_train)
X_test_scale = X_minmax.transform(X_test)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scale, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_train_scale, y_train))
# Out:
# Test Acc: 0.845

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test_scale, y_test))
# Out:
# Test Acc: 0.837

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test_scale)
print(classification_report(y_test, predictions,
                            target_names=disposition_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.69      0.61      0.65       411
#      CONFIRMED       0.70      0.74      0.72       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.84      1748
#      macro avg       0.79      0.78      0.79      1748
#   weighted avg       0.83      0.84      0.83      1748
